# %%
import pandas as pd

# %%
datos = {'nombre': ['Alice', 'Bob', 'Rafa'], 'edad': [25, 30, 35], 'ciudad': ['Madrid', 'Barcelona', 'Valencia']}
datos

# %%
df = pd.DataFrame(datos)
df

# %%
df["nombre"]
type(df["nombre"])

# %%
empleados = {'nombre': ['Ana', 'Luis', 'Carlos'], 'edad': [30, 25, 40]}

df_empleados = pd.DataFrame(empleados)

print(df_empleados)

# %%
empleados = {'nombre': ['Ana', 'Luis', 'Carlos'], 'edad': [30, 25, 40]}

df_empleados = pd.DataFrame(empleados)

shape_df_empleados = df_empleados.shape
columns_df_empleados = df_empleados.columns
index_df_empleados = df_empleados.index

print(shape_df_empleados)
print(columns_df_empleados)
print(index_df_empleados)
