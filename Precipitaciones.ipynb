# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Ricardo\\Downloads\\Precipitaciones.csv")

# %%
df.head()

# %%
df.head()

# %%
df.tail()

# %%
df.shape

# %%
df.columns

# %%
df.info()

# %%
df.describe()

# %%
df.tail(1)

# %%
serie = df["region"]
serie.head()

# %%
datos = [12, 15, 14, 10, 18, 20, 22, 25, 30, 28]

serie2 = pd.Series(datos)
serie2

# %%
indice = ["Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio", "Julio", "Agosto", "Septiembre", "Octubre"]

serie3 = pd.Series(datos, indice)
serie3

# %%
serie3["Marzo"]

# %%
diccionario = {'a': 30, 'b': 70, 'c': 160, 'd': 50}

serie_desde_diccionario = pd.Series(diccionario)
serie_desde_diccionario

# %%
diccionario = {'a': 30, 'b': 70, 'c': 160, 'd': 50}

serie_desde_diccionario = pd.Series(diccionario)

suma_ad = serie_desde_diccionario['a'] + serie_desde_diccionario['d']

def imprimir_suma_ad():
    print(suma_ad)

imprimir_suma_ad()

# %%
lista_numero  = [1, 2, 3, 4, 5]
serie_numero  = pd.Series(lista_numero)
serie_numero[0] = serie_numero[0] + 10
print(serie_numero)

# %%
serie_numero = serie_numero + 10
print(serie_numero)

# %%
serie_numero = serie_numero * 2
print(serie_numero)

# %%
lista1 = [1,2,3,4,5]
lista2 = [6,7,8,9,0]

serie1 = pd.Series(lista1)
serie2 = pd.Series(lista2)

serie_suma = serie1 + serie2

print(serie_suma)

# %%
serie = [1,2,3,4,5,6,7,8,9]

serie_numerica = pd.Series(serie)

serie_doble = serie_numerica * 2

serie_dividida = serie_numerica / 10

print(serie_doble)
print(serie_dividida)

# %%
raiz_cuadrada = serie_grande[8] ** 0.5
print(raiz_cuadrada)
# Out:
# 3.1622776601683795
